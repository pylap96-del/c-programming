# %% [markdown]
# <a href="https://colab.research.google.com/github/pylap96-del/c-programming/blob/main/python_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#arithmetic operations
a=int(input("enter a value"))
b=int(input("enter b value"))
print("addition",a+b)
print("subtraction",a-b)
print("mul",a*b)
print("div",a/b)
print("floor division",a//b)
print("power",a**b)
print("modulus",a%b)
print(f"the sum of {a} and {b} is:",a+b)
# Out:
# enter a value10
# enter b value5
# addition 15
# subtraction 5
# mul 50
# div 2.0
# floor division 2
# power 100000
# modulus 0
# the sum of 10 and 5 is: 15

# %%
kg=float(input("enter weight in kgs"))
pounds=kg*2.20462
print("weight in pounds is:",pounds)
# Out:
# enter weight in kgs35.6
# weight in pounds is: 78.484472

# %%
import math
r=int(input("enter r value"))
a=math.pi*r*r
print("area of circle",a)
# Out:
# enter r value10
# area of circle 314.1592653589793

# %%
name="pavani"
age=18
print(f"Hello my name is {name},I am {age} years old")
# Out:
# Hello my name is pavani,I am 18 years old

# %%
for i in range(9,1000,8):
    print(i, end=" ")

# %%
import random
n = random.randint(1,10)
guess=int(input("enter guess number"))
if guess==n:
  print("correct")
else:
  print("wrong",n)

# %%
import math
r=10
a=2*math.pi*r
print(a)

# %%
a=int(input("enter a value"))
b=int(input("enter b value"))
c=int(input("enter c value"))
print("total",a+b+c)
print("average",(a+b+c)/3)

# %%
name=input("enter your name:")
n=int(input("no of times"))
for i in range(n):
        print(name)

# %%
n=int(input("height of triangle"))
for i in range(1,n+1):
      print("*" * i)
      print(i)

# %%
import math
b=int(input("enter b value"))
a=math.sqrt(b)
print(a)

# %%
a = float(input("enter first value"))
b = float(input("enter second value"))
if abs(a-b) <=0.001:
   print("close")
else:
   print("not close")

# %%
s= input("enter a string;").lower()
vowels="aeiou"
found = False
for ch in s:
  if ch in vowels:
    found=True
    break
if found:
  print("vowels present")
else:
  print(" no vowels found")
